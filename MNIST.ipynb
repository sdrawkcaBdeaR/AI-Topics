# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import datasets,layers,models
# Out:
# 2023-02-02 11:18:01.448287: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
(x_train,y_train),(x_test,y_test)=datasets.mnist.load_data()

# %%
plt.imshow(x_train[0])

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train[:5]
# Out:
# array([5, 0, 4, 1, 9], dtype=uint8)

# %%
type(y_train[0])
# Out:
# numpy.uint8

# %%
x_train=x_train/255
x_test=x_test/255

# %%
nn=models.Sequential([
    
    layers.Flatten(input_shape=(28,28)),
    layers.Dense(10,activation='relu'),
    layers.Dense(10,activation='softmax')
])
# Out:
# 2023-01-27 13:04:36.224035: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
nn.compile(optimizer='adam',
           loss='sparse_categorical_crossentropy',
           metrics=['accuracy'])

# %%
nn.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 1s 561us/step - loss: 0.4939 - accuracy: 0.8592
# Epoch 2/10
# 1875/1875 [==============================] - 1s 558us/step - loss: 0.2893 - accuracy: 0.9176
# Epoch 3/10
# 1875/1875 [==============================] - 1s 560us/step - loss: 0.2664 - accuracy: 0.9253
# Epoch 4/10
# 1875/1875 [==============================] - 1s 579us/step - loss: 0.2542 - accuracy: 0.9274
# Epoch 5/10
# 1875/1875 [==============================] - 1s 552us/step - loss: 0.2439 - accuracy: 0.9309
# Epoch 6/10
# 1875/1875 [==============================] - 1s 544us/step - loss: 0.2349 - accuracy: 0.9334
# Epoch 7/10
# 1875/1875 [==============================] - 1s 545us/step - loss: 0.2266 - accuracy: 0.9368
# Epoch 8/10
# 1875/1875 [==============================] - 1s 545us/step - loss: 0.2208 - accuracy: 0.9375
# Epoch 9/10
# 1875/1875 [==============================] - 1s 543us/step - loss: 0.2136 - accuracy: 0.9396
# Epoch 10/10
# 1875/1875 [==============================] - 1s 549us/step - loss: 0.2089 - accuracy: 0.9410

# %%
nn.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 0s 466us/step - loss: 0.2294 - accuracy: 0.9345
# [0.22937975823879242, 0.934499979019165]

# %%
pred=nn.predict(x_test)
# Out:
# 313/313 [==============================] - 0s 400us/step

# %%
def fun(index):
    plt.imshow(x_test[index])
    print('correct value:',y_test[index])
    print('predicted value:',np.argmax(pred[index]))

# %%
fun(0)
# Out:
# correct value: 7
# predicted value: 7

# %%
fun(4)
# Out:
# correct value: 4
# predicted value: 4

# %%
fun(99)
# Out:
# correct value: 9
# predicted value: 9

# %%
fun(9)
# Out:
# correct value: 9
# predicted value: 9
